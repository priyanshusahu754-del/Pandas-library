# %%
import pandas as pd

# %% [markdown]
# # **Reading a .CSV(comma separated value ) files as a pandas data frame**

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # ***Printing the first few rows of the dataframe***

# %%
df.head() # print first 5 rows of the dataframe
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(20) # print first 20 rows of the dataframe
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %% [markdown]
# # ***Printing the last few rows of the dataframe***

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.tail(8)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked
# 883    male  28.0      0      0  C.A./SOTON 34068  10.500   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.050   NaN        S
# ...

# %% [markdown]
# #  **printing the middle  few rows of the dataframe**

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # checking the shape of the dataframe

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # **PRINTING SOME STATISTICS OF YOUR DATAFRAME**

# %%
df.describe() # this gives the summary statistics of your dataframe 

# count: number of non missing values 
# MEAN : 
# STD : standard deviation 
# min : min value of the column 
# 25% : 24 percentile of the column
# 50% : 50 percentile of the column
# 75% : 75 percentile of the column
# max : maximum value of the column
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # **INFO method**

# %%
df.info() # shows the datatypes,number of non-n=missing values in your dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # **selecting and viewing your data**

# %%
df['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
# Selecting multiple column

df[['Name','Age','Survived']]
# Out:
#                                                   Name   Age  Survived
# 0                              Braund, Mr. Owen Harris  22.0         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0         1
# 2                               Heikkinen, Miss. Laina  26.0         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0         1
# 4                             Allen, Mr. William Henry  35.0         0
# ..                                                 ...   ...       ...
# 886                              Montvila, Rev. Juozas  27.0         0
# 887                       Graham, Miss. Margaret Edith  19.0         1
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN         0
# 889                              Behr, Mr. Karl Howell  26.0         1
# 890                                Dooley, Mr. Patrick  32.0         0
#
# [891 rows x 3 columns]

# %%
df[['Pclass','Ticket','Fare','Sex']]
# Out:
#      Pclass            Ticket     Fare     Sex
# 0         3         A/5 21171   7.2500    male
# 1         1          PC 17599  71.2833  female
# 2         3  STON/O2. 3101282   7.9250  female
# 3         1            113803  53.1000  female
# 4         3            373450   8.0500    male
# ..      ...               ...      ...     ...
# 886       2            211536  13.0000    male
# 887       1            112053  30.0000  female
# 888       3        W./C. 6607  23.4500  female
# 889       1            111369  30.0000    male
# 890       3            370376   7.7500    male
#
# [891 rows x 4 columns]

# %% [markdown]
# # Checking missing value in the dataset

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Renaming column in your dataframe

# %%
df.rename(columns={'PassengerId':'S.No.'})  # iss method se column ki real value me koi change nahi hoga 
                                            # bas  ek dataframw me change hoga name jisme hum use karenge
# Out:
#      S.No.  Survived  Pclass  \
# 0        1         0       3
# 1        2         1       1
# 2        3         1       3
# 3        4         1       1
# 4        5         0       3
# ..     ...       ...     ...
# 886    887         0       2
# 887    888         1       1
# 888    889         0       3
# 889    890         1       1
# 890    891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.rename(columns={'PassengerId':'S.No.'} , inplace=True) # inplace use karne se column ki ki value 
df                                                            #real dataframe me bhi change hojayegi aur change hi rhegi
# Out:
#      S.No.  Survived  Pclass  \
# 0        1         0       3
# 1        2         1       1
# 2        3         1       3
# 3        4         1       1
# 4        5         0       3
# ..     ...       ...     ...
# 886    887         0       2
# 887    888         1       1
# 888    889         0       3
# 889    890         1       1
# 890    891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Filtering and Sorting

# %%
df[df['Age']>25]
# Out:
#      S.No.  Survived  Pclass  \
# 1        2         1       1
# 2        3         1       3
# 3        4         1       1
# 4        5         0       3
# 6        7         0       1
# ..     ...       ...     ...
# 883    884         0       2
# 885    886         0       3
# 886    887         0       2
# 889    890         1       1
# 890    891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Age']>50) & (df['Sex']=="male")]
# Out:
#      S.No.  Survived  Pclass                                  Name   Sex  \
# 6        7         0       1               McCarthy, Mr. Timothy J  male
# 33      34         0       2                 Wheadon, Mr. Edward H  male
# 54      55         0       1        Ostby, Mr. Engelhart Cornelius  male
# 94      95         0       3                     Coxon, Mr. Daniel  male
# 96      97         0       1             Goldschmidt, Mr. George B  male
# 116    117         0       3                  Connors, Mr. Patrick  male
# 124    125         0       1           White, Mr. Percival Wayland  male
# 150    151         0       2            Bateman, Rev. Robert James  male
# 152    153         0       3                      Meo, Mr. Alfonzo  male
# 155    156         0       1           Williams, Mr. Charles Duane  male
# 170    171         0       1             Van der hoef, Mr. Wyckoff  male
# 174    175         0       1               Smith, Mr. James Clinch  male
# ...

# %%
df[(df['Age']>50) & (df["Sex"]=="female")][["Name","Age","Sex","Survived"]]
# Out:
#                                                   Name   Age     Sex  Survived
# 11                            Bonnell, Miss. Elizabeth  58.0  female         1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   55.0  female         1
# 195                               Lurette, Miss. Elise  58.0  female         1
# 268      Graham, Mrs. William Thompson (Edith Junkins)  58.0  female         1
# 275                  Andrews, Miss. Kornelia Theodosia  63.0  female         1
# 366   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  60.0  female         1
# 483                             Turkula, Mrs. (Hedwig)  63.0  female         1
# 496                     Eustis, Miss. Elizabeth Mussey  54.0  female         1
# 513     Rothschild, Mrs. Martin (Elizabeth L. Barrett)  54.0  female         1
# 571      Appleton, Mrs. Edward Dale (Charlotte Lamson)  53.0  female         1
# 591    Stephenson, Mrs. Walter Bertram (Martha Eustis)  52.0  female         1
# ...

# %%
df.sort_values('Age',ascending=False) # sort all the rows based on age in descending order
# Out:
#      S.No.  Survived  Pclass                                      Name  \
# 630    631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851    852         0       3                       Svensson, Mr. Johan
# 493    494         0       1                   Artagaveytia, Mr. Ramon
# 96      97         0       1                 Goldschmidt, Mr. George B
# 116    117         0       3                      Connors, Mr. Patrick
# ..     ...       ...     ...                                       ...
# 859    860         0       3                          Razi, Mr. Raihed
# 863    864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868    869         0       3               van Melkebeke, Mr. Philemon
# 878    879         0       3                        Laleff, Mr. Kristo
# 888    889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %%
df[df['Age']==30]
# Out:
#      S.No.  Survived  Pclass  \
# 79      80         1       3
# 157    158         0       3
# 178    179         0       2
# 213    214         0       2
# 219    220         0       2
# 244    245         0       3
# 253    254         0       3
# 257    258         1       1
# 286    287         1       3
# 308    309         0       2
# 309    310         1       1
# 322    323         1       2
# 365    366         0       3
# 418    419         0       2
# 452    453         0       1
# 488    489         0       3
# 520    521         1       1
# 534    535         0       3
# 537    538         1       1
# 606    607         0       3
# 726    727         1       2
# 747    748         1       2
# 798    799         0       3
# 799    800         0       3
# 842    843         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 79                            Dowdell, Miss. Elizabeth  female  30.0      0
# ...

# %%
df[df['Age']==80]
# Out:
#      S.No.  Survived  Pclass                                  Name   Sex  \
# 630    631         1       1  Barkworth, Mr. Algernon Henry Wilson  male
#
#       Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  80.0      0      0  27042  30.0   A23        S

# %% [markdown]
# # Dropping column in your dataframe

# %%
df.drop(columns=['Embarked','Cabin'])  # for changing origional dataframe use inplace=True
# Out:
#      S.No.  Survived  Pclass  \
# 0        1         0       3
# 1        2         1       1
# 2        3         1       3
# 3        4         1       1
# 4        5         0       3
# ..     ...       ...     ...
# 886    887         0       2
# 887    888         1       1
# 888    889         0       3
# 889    890         1       1
# 890    891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      S.No.  Survived  Pclass  \
# 0        1         0       3
# 1        2         1       1
# 2        3         1       3
# 3        4         1       1
# 4        5         0       3
# ..     ...       ...     ...
# 886    887         0       2
# 887    888         1       1
# 888    889         0       3
# 889    890         1       1
# 890    891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(columns=["Embarked","Cabin"] , inplace=True)# for changing origional dataframe use inplace=True

# %%
df
# Out:
#      S.No.  Survived  Pclass  \
# 0        1         0       3
# 1        2         1       1
# 2        3         1       3
# 3        4         1       1
# 4        5         0       3
# ..     ...       ...     ...
# 886    887         0       2
# 887    888         1       1
# 888    889         0       3
# 889    890         1       1
# 890    891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
